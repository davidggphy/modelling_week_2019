# %% [markdown]
# # Classification with Cross Validation (CV) using xgboost algorithm

# %% [markdown]
# The first problem we have to attack is to define a metric we want to maximize (or minimize if it is a loss), and we will use it to select the best (or bests) models and hyperparameters. In order to understand the mechanism, we will code the validation loop by hand, and then we will use sklearn functions which do it automatically.
#
# Although we are only interested in the metric on the validation set, it is interesting to compare it with the metric on the training set, to check the presence of overfitting.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import scipy
import sklearn
import xgboost as xgb
from xgboost_utils import F1_eval
# plt.style.use('fivethirtyeight')
sns.set_style("whitegrid")
sns.set_context("notebook")
DATA_PATH = '../data/'

VAL_SPLITS = 4

# %%
from plot_utils import plot_confusion_matrix
from cv_utils import run_cv_f1
from cv_utils import plot_cv_roc
from cv_utils import plot_cv_roc_prc
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %% [markdown]
# For this part of the project, we will only work with the training set, that we will split again into train and validation to perform the hyperparameter tuning.
#
# We will save the test set for the final part, when we have already tuned our hyperparameters.

# %%
df = pd.read_csv(os.path.join(DATA_PATH,'df_train.csv'))
df.drop(columns= df.columns[0:2],inplace=True)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.829392  1.118573  0.926038  1.163686  0.009824  0.527347  0.173370
# 1 -2.814527  1.613321  0.654307  0.581821  0.399491  0.730040  0.456233
# 2  2.105028 -0.700400 -1.338043 -0.596395 -0.395217 -0.755050 -0.276951
# 3  2.205839 -1.023897 -1.270137 -0.950174 -0.868712 -0.975492 -0.475464
# 4  2.027090 -0.778666 -1.552755 -0.558679  0.020939 -0.026071 -0.207810
#
#          V8        V9       V10  ...       V24       V25       V26       V27  \
# 0  0.723997 -0.638939 -0.162923  ... -0.298908 -0.060301 -0.217935  0.291312
# 1 -2.464347  0.654797  2.248682  ... -0.329526 -0.307374 -0.440007 -2.135657
# 2 -0.291562 -0.965418  1.107179  ... -0.278137 -0.040685  0.789267 -0.066054
# 3 -0.280564  0.503713  0.448173  ... -0.041177  0.089158  1.105794 -0.066285
# 4 -0.124288 -0.635953  0.817757  ...  0.033477 -0.157992 -0.606327 -0.003931
#
#         V28  Class  TimeScaled   TimeSin   TimeCos  AmountBC
# 0  0.120779      0    0.460069 -0.480989  0.876727  3.195062
# 1  0.011041      0    0.266395 -0.204567 -0.978853  3.125269
# 2 -0.069956      0    0.762303 -0.153992 -0.988072  3.421235
# 3 -0.079881      0    0.879740 -0.998227  0.059524  1.072145
# 4 -0.039868      0    0.821649 -0.783558 -0.621319  3.971490
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Using xgboost in Python

# %%
cv = StratifiedShuffleSplit(n_splits=VAL_SPLITS,test_size=0.15,random_state=0)
clf = xgb.sklearn.XGBClassifier(n_jobs=-1,eval_metric='auc',verbosity=1)

# In case we want to select a subset of features
df_ = df[['Class','V9','V14','V16']]
X = df_.drop(columns='Class').to_numpy()
y = df_['Class'].to_numpy()

metrics = cross_val_score(clf,X,y,cv=cv,scoring='f1',n_jobs=-1)
print('F1 value (Val): {:.2f} ± {:.2f}'.format(
                np.mean(metrics),
                np.std(metrics, ddof=1)
            ))

# %%
cv = StratifiedShuffleSplit(n_splits=VAL_SPLITS,test_size=0.15,random_state=0)
clf = xgb.sklearn.XGBClassifier(n_jobs=-1,verbosity=1)
# In case we want to select a subset of features
df_ = df[['Class','V9','V14','V16']]
X = df_.drop(columns='Class').to_numpy()
y = df_['Class'].to_numpy()

for idx_t,idx_v in cv.split(X,y):
    X_train = X[idx_t]
    y_train = y[idx_t]
    X_val = X[idx_v]
    y_val = y[idx_v]
    clf.fit(X_train,y_train,eval_metric=F1_eval,eval_set=[(X_val,y_val)],early_stopping_rounds=25)
    break
# Out:
# [0]	validation_0-error:0.000829	validation_0-f1_err:0.294118
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.000829	validation_0-f1_err:0.294118
# [2]	validation_0-error:0.000829	validation_0-f1_err:0.27619
# [3]	validation_0-error:0.000802	validation_0-f1_err:0.271028
# [4]	validation_0-error:0.000802	validation_0-f1_err:0.271028
# [5]	validation_0-error:0.000802	validation_0-f1_err:0.259259
# [6]	validation_0-error:0.000802	validation_0-f1_err:0.259259
# [7]	validation_0-error:0.000774	validation_0-f1_err:0.259259
# [8]	validation_0-error:0.000802	validation_0-f1_err:0.259259
# [9]	validation_0-error:0.000774	validation_0-f1_err:0.259259
# [10]	validation_0-error:0.000774	validation_0-f1_err:0.259259
# [11]	validation_0-error:0.000746	validation_0-f1_err:0.245283
# [12]	validation_0-error:0.000719	validation_0-f1_err:0.245283
# [13]	validation_0-error:0.000719	validation_0-f1_err:0.245283
# [14]	validation_0-error:0.000719	validation_0-f1_err:0.245283
# [15]	validation_0-error:0.000719	validation_0-f1_err:0.243697
# [16]	validation_0-error:0.000746	validation_0-f1_err:0.241379
# [17]	validation_0-error:0.000746	validation_0-f1_err:0.233333
# [18]	validation_0-error:0.000746	validation_0-f1_err:0.234783
# [19]	validation_0-error:0.000746	validation_0-f1_err:0.22314
# [20]	validation_0-error:0.000746	validation_0-f1_err:0.22314
# [21]	validation_0-error:0.000746	validation_0-f1_err:0.22314
# [22]	validation_0-error:0.000746	validation_0-f1_err:0.22314
# [23]	validation_0-error:0.000746	validation_0-f1_err:0.220339
# [24]	validation_0-error:0.000719	validation_0-f1_err:0.220339
# [25]	validation_0-error:0.000719	validation_0-f1_err:0.213675
# [26]	validation_0-error:0.000719	validation_0-f1_err:0.213675
# [27]	validation_0-error:0.000719	validation_0-f1_err:0.206897
# [28]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [29]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [30]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [31]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [32]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [33]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [34]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [35]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [36]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [37]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [38]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [39]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [40]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [41]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [42]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [43]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [44]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [45]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [46]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [47]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [48]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [49]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [50]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [51]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [52]	validation_0-error:0.000746	validation_0-f1_err:0.2
# [53]	validation_0-error:0.000746	validation_0-f1_err:0.2
# Stopping. Best iteration:
# [28]	validation_0-error:0.000719	validation_0-f1_err:0.2

# %%
cv = StratifiedShuffleSplit(n_splits=1,test_size=0.15,random_state=0).get_n_splits
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-d55c043fad04> in <module>
#       1 cv = StratifiedShuffleSplit(n_splits=1,test_size=0.15,random_state=0)
# ----> 2 cv.get_nplits()
#
# AttributeError: 'StratifiedShuffleSplit' object has no attribute 'get_nplits'

# %%
cv = StratifiedShuffleSplit(n_splits=VAL_SPLITS,test_size=0.15,random_state=0)
clf = xgb.sklearn.XGBClassifier(n_jobs=-1,verbosity=1)

# In case we want to select a subset of features
df_ = df
X = df_.drop(columns='Class').to_numpy()
y = df_['Class'].to_numpy()

# We create two eampty lists to save the metrics at each fold for train and validation. 
metrics = []
metrics_train = []
# Loop over the different validation folds
for i,(idx_t, idx_v) in enumerate(cv.split(X,y)):
    X_train = X[idx_t]
    y_train = y[idx_t]
    X_val = X[idx_v]
    y_val = y[idx_v]
    
    clf.fit(X_train,y_train,eval_metric=F1_eval,eval_set=[(X_val,y_val)],early_stopping_rounds=25)
    
    y_pred = clf.predict(X_val)
    metric = f1_score(y_val,y_pred)
    metrics.append(metric)
    
    y_t_pred = clf.predict(X_train)
    metric_train = f1_score(y_train,y_t_pred)
    metrics_train.append(metric_train)
    
    print('{}-fold / {} completed!'.format(i+1,cv.get_n_splits()))
    
metric_mean = np.mean(metrics)
metric_std = np.std(metrics, ddof=1)
metric_t_mean = np.mean(metrics_train)
metric_t_std = np.std(metrics_train, ddof=1)
print('Metric value (Train): {:.2f} ± {:.2f}'.format(metric_t_mean,metric_t_std))
print('Metric value(Val): {:.2f} ± {:.2f}'.format(metric_mean,metric_std))
# Out:
# [0]	validation_0-error:0.000857	validation_0-f1_err:0.263158
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.000829	validation_0-f1_err:0.263158
# [2]	validation_0-error:0.000829	validation_0-f1_err:0.263158
# [3]	validation_0-error:0.000829	validation_0-f1_err:0.256637
# [4]	validation_0-error:0.000802	validation_0-f1_err:0.256637
# [5]	validation_0-error:0.000802	validation_0-f1_err:0.25
# [6]	validation_0-error:0.000802	validation_0-f1_err:0.254545
# [7]	validation_0-error:0.000802	validation_0-f1_err:0.252174
# [8]	validation_0-error:0.000802	validation_0-f1_err:0.245614
# [9]	validation_0-error:0.000802	validation_0-f1_err:0.243243
# [10]	validation_0-error:0.000802	validation_0-f1_err:0.239669
# [11]	validation_0-error:0.000802	validation_0-f1_err:0.233333
# [12]	validation_0-error:0.000719	validation_0-f1_err:0.232143
# [13]	validation_0-error:0.000719	validation_0-f1_err:0.213675
# [14]	validation_0-error:0.000691	validation_0-f1_err:0.213675
# [15]	validation_0-error:0.000691	validation_0-f1_err:0.213675
# [16]	validation_0-error:0.000691	validation_0-f1_err:0.213675
# [17]	validation_0-error:0.000719	validation_0-f1_err:0.20354
# [18]	validation_0-error:0.000719	validation_0-f1_err:0.2
# [19]	validation_0-error:0.000663	validation_0-f1_err:0.2
# [20]	validation_0-error:0.000663	validation_0-f1_err:0.2
# [21]	validation_0-error:0.000663	validation_0-f1_err:0.20354
# [22]	validation_0-error:0.000636	validation_0-f1_err:0.2
# [23]	validation_0-error:0.000636	validation_0-f1_err:0.192982
# [24]	validation_0-error:0.000608	validation_0-f1_err:0.192982
# [25]	validation_0-error:0.000636	validation_0-f1_err:0.192982
# [26]	validation_0-error:0.000636	validation_0-f1_err:0.192982
# [27]	validation_0-error:0.000636	validation_0-f1_err:0.192982
# [28]	validation_0-error:0.000608	validation_0-f1_err:0.192982
# [29]	validation_0-error:0.000608	validation_0-f1_err:0.192982
# [30]	validation_0-error:0.000636	validation_0-f1_err:0.192982
# [31]	validation_0-error:0.000663	validation_0-f1_err:0.192982
# [32]	validation_0-error:0.000663	validation_0-f1_err:0.192982
# [33]	validation_0-error:0.000691	validation_0-f1_err:0.2
# [34]	validation_0-error:0.000663	validation_0-f1_err:0.2
# [35]	validation_0-error:0.000636	validation_0-f1_err:0.2
# [36]	validation_0-error:0.00058	validation_0-f1_err:0.192661
# [37]	validation_0-error:0.000663	validation_0-f1_err:0.2
# [38]	validation_0-error:0.000608	validation_0-f1_err:0.2
# [39]	validation_0-error:0.000608	validation_0-f1_err:0.196429
# [40]	validation_0-error:0.000608	validation_0-f1_err:0.2
# [41]	validation_0-error:0.000608	validation_0-f1_err:0.192661
# [42]	validation_0-error:0.000608	validation_0-f1_err:0.196429
# [43]	validation_0-error:0.000636	validation_0-f1_err:0.196429
# [44]	validation_0-error:0.000636	validation_0-f1_err:0.196429
# [45]	validation_0-error:0.000663	validation_0-f1_err:0.196429
# [46]	validation_0-error:0.000636	validation_0-f1_err:0.196429
# [47]	validation_0-error:0.000636	validation_0-f1_err:0.196429
# [48]	validation_0-error:0.000663	validation_0-f1_err:0.196429
# [49]	validation_0-error:0.000636	validation_0-f1_err:0.203704
# [50]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [51]	validation_0-error:0.000608	validation_0-f1_err:0.196262
# [52]	validation_0-error:0.000608	validation_0-f1_err:0.196262
# [53]	validation_0-error:0.000608	validation_0-f1_err:0.196262
# [54]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [55]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [56]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [57]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [58]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [59]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [60]	validation_0-error:0.000636	validation_0-f1_err:0.196262
# [61]	validation_0-error:0.000636	validation_0-f1_err:0.20354
# Stopping. Best iteration:
# [36]	validation_0-error:0.00058	validation_0-f1_err:0.192661
#
# 1-fold / 4 completed!
# [0]	validation_0-error:0.001133	validation_0-f1_err:0.356522
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.001078	validation_0-f1_err:0.321101
# [2]	validation_0-error:0.001078	validation_0-f1_err:0.321101
# [3]	validation_0-error:0.001133	validation_0-f1_err:0.327103
# [4]	validation_0-error:0.001106	validation_0-f1_err:0.327273
# [5]	validation_0-error:0.001106	validation_0-f1_err:0.321101
# [6]	validation_0-error:0.001106	validation_0-f1_err:0.32
# [7]	validation_0-error:0.001023	validation_0-f1_err:0.306931
# [8]	validation_0-error:0.001023	validation_0-f1_err:0.295238
# [9]	validation_0-error:0.001023	validation_0-f1_err:0.294118
# [10]	validation_0-error:0.000995	validation_0-f1_err:0.295238
# [11]	validation_0-error:0.000995	validation_0-f1_err:0.294118
# [12]	validation_0-error:0.00094	validation_0-f1_err:0.294118
# [13]	validation_0-error:0.00094	validation_0-f1_err:0.290909
# [14]	validation_0-error:0.00094	validation_0-f1_err:0.282051
# [15]	validation_0-error:0.00094	validation_0-f1_err:0.282051
# [16]	validation_0-error:0.00094	validation_0-f1_err:0.269565
# [17]	validation_0-error:0.000885	validation_0-f1_err:0.269565
# [18]	validation_0-error:0.000829	validation_0-f1_err:0.259259
# [19]	validation_0-error:0.000802	validation_0-f1_err:0.25
# [20]	validation_0-error:0.000774	validation_0-f1_err:0.25
# [21]	validation_0-error:0.000774	validation_0-f1_err:0.236364
# [22]	validation_0-error:0.000774	validation_0-f1_err:0.236364
# [23]	validation_0-error:0.000746	validation_0-f1_err:0.236364
# [24]	validation_0-error:0.000746	validation_0-f1_err:0.236364
# [25]	validation_0-error:0.000719	validation_0-f1_err:0.229358
# [26]	validation_0-error:0.000719	validation_0-f1_err:0.236364
# [27]	validation_0-error:0.000719	validation_0-f1_err:0.229358
# [28]	validation_0-error:0.000719	validation_0-f1_err:0.229358
# [29]	validation_0-error:0.000719	validation_0-f1_err:0.229358
# [30]	validation_0-error:0.000719	validation_0-f1_err:0.229358
# [31]	validation_0-error:0.000719	validation_0-f1_err:0.225225
# [32]	validation_0-error:0.000691	validation_0-f1_err:0.225225
# [33]	validation_0-error:0.000691	validation_0-f1_err:0.221239
# [34]	validation_0-error:0.000719	validation_0-f1_err:0.218182
# [35]	validation_0-error:0.000719	validation_0-f1_err:0.218182
# [36]	validation_0-error:0.000691	validation_0-f1_err:0.214286
# [37]	validation_0-error:0.000691	validation_0-f1_err:0.214286
# [38]	validation_0-error:0.000691	validation_0-f1_err:0.214286
# [39]	validation_0-error:0.000691	validation_0-f1_err:0.214286
# [40]	validation_0-error:0.000691	validation_0-f1_err:0.214286
# [41]	validation_0-error:0.000691	validation_0-f1_err:0.218182
# [42]	validation_0-error:0.000691	validation_0-f1_err:0.218182
# [43]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [44]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [45]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [46]	validation_0-error:0.000691	validation_0-f1_err:0.207207
# [47]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [48]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [49]	validation_0-error:0.000691	validation_0-f1_err:0.207207
# [50]	validation_0-error:0.000719	validation_0-f1_err:0.207207
# [51]	validation_0-error:0.000719	validation_0-f1_err:0.207207
# [52]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [53]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [54]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [55]	validation_0-error:0.000691	validation_0-f1_err:0.207207
# [56]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [57]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [58]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [59]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [60]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [61]	validation_0-error:0.000691	validation_0-f1_err:0.207207
# [62]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [63]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [64]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [65]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [66]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [67]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# [68]	validation_0-error:0.000663	validation_0-f1_err:0.207207
# Stopping. Best iteration:
# [43]	validation_0-error:0.000663	validation_0-f1_err:0.207207
#
# 2-fold / 4 completed!
# [0]	validation_0-error:0.000553	validation_0-f1_err:0.181818
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.000553	validation_0-f1_err:0.171171
# [2]	validation_0-error:0.000553	validation_0-f1_err:0.171171
# [3]	validation_0-error:0.000553	validation_0-f1_err:0.171171
# [4]	validation_0-error:0.000553	validation_0-f1_err:0.168142
# [5]	validation_0-error:0.000525	validation_0-f1_err:0.168142
# [6]	validation_0-error:0.000525	validation_0-f1_err:0.160714
# [7]	validation_0-error:0.000525	validation_0-f1_err:0.160714
# [8]	validation_0-error:0.000525	validation_0-f1_err:0.160714
# [9]	validation_0-error:0.000525	validation_0-f1_err:0.160714
# [10]	validation_0-error:0.000525	validation_0-f1_err:0.155963
# [11]	validation_0-error:0.000498	validation_0-f1_err:0.155963
# [12]	validation_0-error:0.000498	validation_0-f1_err:0.148148
# [13]	validation_0-error:0.000525	validation_0-f1_err:0.150442
# [14]	validation_0-error:0.000525	validation_0-f1_err:0.150442
# [15]	validation_0-error:0.000498	validation_0-f1_err:0.154472
# [16]	validation_0-error:0.000498	validation_0-f1_err:0.147541
# [17]	validation_0-error:0.000525	validation_0-f1_err:0.140496
# [18]	validation_0-error:0.000498	validation_0-f1_err:0.147541
# [19]	validation_0-error:0.000498	validation_0-f1_err:0.147541
# [20]	validation_0-error:0.000498	validation_0-f1_err:0.142857
# [21]	validation_0-error:0.000498	validation_0-f1_err:0.133333
# [22]	validation_0-error:0.000498	validation_0-f1_err:0.135593
# [23]	validation_0-error:0.000498	validation_0-f1_err:0.12605
# [24]	validation_0-error:0.000498	validation_0-f1_err:0.12605
# [25]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [26]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [27]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [28]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [29]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [30]	validation_0-error:0.000525	validation_0-f1_err:0.12605
# [31]	validation_0-error:0.000498	validation_0-f1_err:0.12605
# [32]	validation_0-error:0.00047	validation_0-f1_err:0.12605
# [33]	validation_0-error:0.00047	validation_0-f1_err:0.12605
# [34]	validation_0-error:0.00047	validation_0-f1_err:0.12605
# [35]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [36]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [37]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [38]	validation_0-error:0.000498	validation_0-f1_err:0.118644
# [39]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [40]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [41]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [42]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [43]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [44]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [45]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [46]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [47]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [48]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [49]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [50]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [51]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [52]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [53]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [54]	validation_0-error:0.00047	validation_0-f1_err:0.118644
# [55]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [56]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [57]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [58]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [59]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [60]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [61]	validation_0-error:0.00047	validation_0-f1_err:0.111111
# [62]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [63]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [64]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [65]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [66]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [67]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [68]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [69]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [70]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [71]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [72]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [73]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [74]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [75]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [76]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [77]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [78]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [79]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# [80]	validation_0-error:0.000442	validation_0-f1_err:0.111111
# Stopping. Best iteration:
# [55]	validation_0-error:0.00047	validation_0-f1_err:0.111111
#
# 3-fold / 4 completed!
# [0]	validation_0-error:0.000746	validation_0-f1_err:0.217391
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.000746	validation_0-f1_err:0.217391
# [2]	validation_0-error:0.000746	validation_0-f1_err:0.217391
# [3]	validation_0-error:0.000746	validation_0-f1_err:0.206897
# [4]	validation_0-error:0.000802	validation_0-f1_err:0.206897
# [5]	validation_0-error:0.000802	validation_0-f1_err:0.206897
# [6]	validation_0-error:0.000719	validation_0-f1_err:0.206897
# [7]	validation_0-error:0.000663	validation_0-f1_err:0.206897
# [8]	validation_0-error:0.000636	validation_0-f1_err:0.196429
# [9]	validation_0-error:0.000663	validation_0-f1_err:0.206897
# [10]	validation_0-error:0.000691	validation_0-f1_err:0.193277
# [11]	validation_0-error:0.000691	validation_0-f1_err:0.190083
# [12]	validation_0-error:0.000719	validation_0-f1_err:0.190083
# [13]	validation_0-error:0.000719	validation_0-f1_err:0.186441
# [14]	validation_0-error:0.000663	validation_0-f1_err:0.186441
# [15]	validation_0-error:0.000663	validation_0-f1_err:0.190083
# [16]	validation_0-error:0.000663	validation_0-f1_err:0.183333
# [17]	validation_0-error:0.000663	validation_0-f1_err:0.183333
# [18]	validation_0-error:0.000691	validation_0-f1_err:0.176471
# [19]	validation_0-error:0.000719	validation_0-f1_err:0.176471
# [20]	validation_0-error:0.000691	validation_0-f1_err:0.176471
# [21]	validation_0-error:0.000691	validation_0-f1_err:0.176471
# [22]	validation_0-error:0.000691	validation_0-f1_err:0.176471
# [23]	validation_0-error:0.000636	validation_0-f1_err:0.176471
# [24]	validation_0-error:0.000691	validation_0-f1_err:0.176471
# [25]	validation_0-error:0.000636	validation_0-f1_err:0.176471
# [26]	validation_0-error:0.000663	validation_0-f1_err:0.176471
# [27]	validation_0-error:0.000663	validation_0-f1_err:0.176471
# [28]	validation_0-error:0.000636	validation_0-f1_err:0.176471
# [29]	validation_0-error:0.000608	validation_0-f1_err:0.176471
# [30]	validation_0-error:0.000608	validation_0-f1_err:0.176471
# [31]	validation_0-error:0.000636	validation_0-f1_err:0.172414
# [32]	validation_0-error:0.000636	validation_0-f1_err:0.172414
# [33]	validation_0-error:0.000636	validation_0-f1_err:0.165217
# [34]	validation_0-error:0.000636	validation_0-f1_err:0.165217
# [35]	validation_0-error:0.000608	validation_0-f1_err:0.165217
# [36]	validation_0-error:0.000608	validation_0-f1_err:0.165217
# [37]	validation_0-error:0.000608	validation_0-f1_err:0.162393
# [38]	validation_0-error:0.000608	validation_0-f1_err:0.162393
# [39]	validation_0-error:0.000608	validation_0-f1_err:0.162393
# [40]	validation_0-error:0.000608	validation_0-f1_err:0.155172
# [41]	validation_0-error:0.000608	validation_0-f1_err:0.155172
# [42]	validation_0-error:0.000608	validation_0-f1_err:0.155172
# [43]	validation_0-error:0.000608	validation_0-f1_err:0.155172
# [44]	validation_0-error:0.00058	validation_0-f1_err:0.155172
# [45]	validation_0-error:0.00058	validation_0-f1_err:0.155172
# [46]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [47]	validation_0-error:0.00058	validation_0-f1_err:0.155172
# [48]	validation_0-error:0.00058	validation_0-f1_err:0.155172
# [49]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [50]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [51]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [52]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [53]	validation_0-error:0.000553	validation_0-f1_err:0.152542
# [54]	validation_0-error:0.000553	validation_0-f1_err:0.159664
# [55]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [56]	validation_0-error:0.000553	validation_0-f1_err:0.157895
# [57]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [58]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [59]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [60]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [61]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [62]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [63]	validation_0-error:0.00058	validation_0-f1_err:0.155172
# [64]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [65]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [66]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [67]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [68]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [69]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [70]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [71]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [72]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [73]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [74]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [75]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [76]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [77]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# [78]	validation_0-error:0.000553	validation_0-f1_err:0.155172
# Stopping. Best iteration:
# [53]	validation_0-error:0.000553	validation_0-f1_err:0.152542
#
# 4-fold / 4 completed!
# Metric value (Train): 0.88 ± 0.01
# Metric value(Val): 0.82 ± 0.03

# %%
cv = StratifiedShuffleSplit(n_splits=VAL_SPLITS,test_size=0.15,random_state=0)
clf = xgb.sklearn.XGBClassifier(n_jobs=-1,verbosity=0)

# In case we want to select a subset of features
df_ = df
X = df_.drop(columns='Class').to_numpy()
y = df_['Class'].to_numpy()

# We create two eampty lists to save the metrics at each fold for train and validation. 
metrics = []
metrics_train = []
# Loop over the different validation folds
for i,(idx_t, idx_v) in enumerate(cv.split(X,y)):
    X_train = X[idx_t]
    y_train = y[idx_t]
    X_val = X[idx_v]
    y_val = y[idx_v]
    
    clf.fit(X_train,y_train,
            eval_metric=F1_eval,
            eval_set=[(X_val,y_val)],
            early_stopping_rounds=25,
            sample_weight= (1+y_train/y_train.mean()))
    
    y_pred = clf.predict(X_val)
    metric = f1_score(y_val,y_pred)
    metrics.append(metric)
    
    y_t_pred = clf.predict(X_train)
    metric_train = f1_score(y_train,y_t_pred)
    metrics_train.append(metric_train)
    
    print('{}-fold / {} completed!'.format(i+1,cv.get_n_splits()))
    
metric_mean = np.mean(metrics)
metric_std = np.std(metrics, ddof=1)
metric_t_mean = np.mean(metrics_train)
metric_t_std = np.std(metrics_train, ddof=1)
print('Metric value (Train): {:.2f} ± {:.2f}'.format(metric_t_mean,metric_t_std))
print('Metric value(Val): {:.2f} ± {:.2f}'.format(metric_mean,metric_std))
# Out:
# [0]	validation_0-error:0.058132	validation_0-f1_err:0.502825
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.040192	validation_0-f1_err:0.362319
# [2]	validation_0-error:0.029522	validation_0-f1_err:0.362319
# [3]	validation_0-error:0.02709	validation_0-f1_err:0.263158
# [4]	validation_0-error:0.028665	validation_0-f1_err:0.252174
# [5]	validation_0-error:0.026482	validation_0-f1_err:0.263158
# [6]	validation_0-error:0.021921	validation_0-f1_err:0.263158
# [7]	validation_0-error:0.020456	validation_0-f1_err:0.263158
# [8]	validation_0-error:0.020373	validation_0-f1_err:0.233645
# [9]	validation_0-error:0.02181	validation_0-f1_err:0.233645
# [10]	validation_0-error:0.01841	validation_0-f1_err:0.226415
# [11]	validation_0-error:0.019709	validation_0-f1_err:0.226415
# [12]	validation_0-error:0.017083	validation_0-f1_err:0.226415
# [13]	validation_0-error:0.01736	validation_0-f1_err:0.226415
# [14]	validation_0-error:0.017581	validation_0-f1_err:0.226415
# [15]	validation_0-error:0.016558	validation_0-f1_err:0.226415
# [16]	validation_0-error:0.016116	validation_0-f1_err:0.232143
# [17]	validation_0-error:0.015646	validation_0-f1_err:0.243243
# [18]	validation_0-error:0.014872	validation_0-f1_err:0.241379
# [19]	validation_0-error:0.014982	validation_0-f1_err:0.232143
# [20]	validation_0-error:0.014789	validation_0-f1_err:0.226415
# [21]	validation_0-error:0.013987	validation_0-f1_err:0.229358
# [22]	validation_0-error:0.014015	validation_0-f1_err:0.225225
# [23]	validation_0-error:0.014927	validation_0-f1_err:0.221239
# [24]	validation_0-error:0.014899	validation_0-f1_err:0.225225
# [25]	validation_0-error:0.014181	validation_0-f1_err:0.214286
# [26]	validation_0-error:0.013655	validation_0-f1_err:0.222222
# [27]	validation_0-error:0.013628	validation_0-f1_err:0.214286
# [28]	validation_0-error:0.013462	validation_0-f1_err:0.214286
# [29]	validation_0-error:0.013324	validation_0-f1_err:0.214953
# [30]	validation_0-error:0.013407	validation_0-f1_err:0.214953
# [31]	validation_0-error:0.013407	validation_0-f1_err:0.214953
# [32]	validation_0-error:0.013794	validation_0-f1_err:0.214953
# [33]	validation_0-error:0.013268	validation_0-f1_err:0.210526
# [34]	validation_0-error:0.013655	validation_0-f1_err:0.214953
# [35]	validation_0-error:0.013213	validation_0-f1_err:0.214953
# [36]	validation_0-error:0.013241	validation_0-f1_err:0.214953
# [37]	validation_0-error:0.013766	validation_0-f1_err:0.2
# [38]	validation_0-error:0.013738	validation_0-f1_err:0.214286
# [39]	validation_0-error:0.013655	validation_0-f1_err:0.203704
# [40]	validation_0-error:0.013241	validation_0-f1_err:0.214286
# [41]	validation_0-error:0.012826	validation_0-f1_err:0.2
# [42]	validation_0-error:0.012633	validation_0-f1_err:0.211009
# [43]	validation_0-error:0.012494	validation_0-f1_err:0.211009
# [44]	validation_0-error:0.012384	validation_0-f1_err:0.207207
# [45]	validation_0-error:0.012329	validation_0-f1_err:0.207207
# [46]	validation_0-error:0.012439	validation_0-f1_err:0.207207
# [47]	validation_0-error:0.012439	validation_0-f1_err:0.207207
# [48]	validation_0-error:0.012273	validation_0-f1_err:0.2
# [49]	validation_0-error:0.01255	validation_0-f1_err:0.211009
# [50]	validation_0-error:0.012494	validation_0-f1_err:0.211009
# [51]	validation_0-error:0.011942	validation_0-f1_err:0.207207
# [52]	validation_0-error:0.012301	validation_0-f1_err:0.210526
# [53]	validation_0-error:0.011914	validation_0-f1_err:0.210526
# [54]	validation_0-error:0.011831	validation_0-f1_err:0.210526
# [55]	validation_0-error:0.01208	validation_0-f1_err:0.210526
# [56]	validation_0-error:0.012025	validation_0-f1_err:0.211009
# [57]	validation_0-error:0.011914	validation_0-f1_err:0.20354
# [58]	validation_0-error:0.011416	validation_0-f1_err:0.20354
# [59]	validation_0-error:0.01114	validation_0-f1_err:0.20354
# [60]	validation_0-error:0.010919	validation_0-f1_err:0.20354
# [61]	validation_0-error:0.011085	validation_0-f1_err:0.20354
# [62]	validation_0-error:0.010753	validation_0-f1_err:0.20354
# Stopping. Best iteration:
# [37]	validation_0-error:0.013766	validation_0-f1_err:0.2
#
# 1-fold / 4 completed!
# [0]	validation_0-error:0.027034	validation_0-f1_err:0.432432
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.044145	validation_0-f1_err:0.432432
# [2]	validation_0-error:0.045113	validation_0-f1_err:0.391304
# [3]	validation_0-error:0.03002	validation_0-f1_err:0.338583
# [4]	validation_0-error:0.022916	validation_0-f1_err:0.328
# [5]	validation_0-error:0.023137	validation_0-f1_err:0.328
# [6]	validation_0-error:0.019488	validation_0-f1_err:0.328
# [7]	validation_0-error:0.015535	validation_0-f1_err:0.328
# [8]	validation_0-error:0.014927	validation_0-f1_err:0.322581
# [9]	validation_0-error:0.01454	validation_0-f1_err:0.293103
# [10]	validation_0-error:0.014982	validation_0-f1_err:0.293103
# [11]	validation_0-error:0.01396	validation_0-f1_err:0.293103
# [12]	validation_0-error:0.014457	validation_0-f1_err:0.261261
# [13]	validation_0-error:0.013932	validation_0-f1_err:0.254545
# [14]	validation_0-error:0.013462	validation_0-f1_err:0.261261
# [15]	validation_0-error:0.013407	validation_0-f1_err:0.261261
# [16]	validation_0-error:0.013683	validation_0-f1_err:0.261261
# [17]	validation_0-error:0.013351	validation_0-f1_err:0.261261
# [18]	validation_0-error:0.013434	validation_0-f1_err:0.261261
# [19]	validation_0-error:0.013711	validation_0-f1_err:0.261261
# [20]	validation_0-error:0.013766	validation_0-f1_err:0.261261
# [21]	validation_0-error:0.013849	validation_0-f1_err:0.272727
# [22]	validation_0-error:0.013324	validation_0-f1_err:0.266667
# [23]	validation_0-error:0.01302	validation_0-f1_err:0.241379
# [24]	validation_0-error:0.01313	validation_0-f1_err:0.234783
# [25]	validation_0-error:0.012826	validation_0-f1_err:0.238938
# [26]	validation_0-error:0.01313	validation_0-f1_err:0.232143
# [27]	validation_0-error:0.01313	validation_0-f1_err:0.232143
# [28]	validation_0-error:0.013268	validation_0-f1_err:0.232143
# [29]	validation_0-error:0.013103	validation_0-f1_err:0.232143
# [30]	validation_0-error:0.012909	validation_0-f1_err:0.232143
# [31]	validation_0-error:0.013379	validation_0-f1_err:0.232143
# [32]	validation_0-error:0.013158	validation_0-f1_err:0.232143
# [33]	validation_0-error:0.013047	validation_0-f1_err:0.221239
# [34]	validation_0-error:0.013075	validation_0-f1_err:0.221239
# [35]	validation_0-error:0.012937	validation_0-f1_err:0.221239
# [36]	validation_0-error:0.013047	validation_0-f1_err:0.221239
# [37]	validation_0-error:0.012633	validation_0-f1_err:0.22807
# [38]	validation_0-error:0.012577	validation_0-f1_err:0.221239
# [39]	validation_0-error:0.01313	validation_0-f1_err:0.232143
# [40]	validation_0-error:0.013103	validation_0-f1_err:0.22807
# [41]	validation_0-error:0.012494	validation_0-f1_err:0.232143
# [42]	validation_0-error:0.013103	validation_0-f1_err:0.232143
# [43]	validation_0-error:0.013103	validation_0-f1_err:0.232143
# [44]	validation_0-error:0.012964	validation_0-f1_err:0.232143
# [45]	validation_0-error:0.013047	validation_0-f1_err:0.232143
# [46]	validation_0-error:0.012688	validation_0-f1_err:0.232143
# [47]	validation_0-error:0.013075	validation_0-f1_err:0.232143
# [48]	validation_0-error:0.013296	validation_0-f1_err:0.232143
# [49]	validation_0-error:0.013158	validation_0-f1_err:0.234783
# [50]	validation_0-error:0.01266	validation_0-f1_err:0.241379
# [51]	validation_0-error:0.012329	validation_0-f1_err:0.241379
# [52]	validation_0-error:0.01266	validation_0-f1_err:0.241379
# [53]	validation_0-error:0.012384	validation_0-f1_err:0.241379
# [54]	validation_0-error:0.01219	validation_0-f1_err:0.241379
# [55]	validation_0-error:0.012163	validation_0-f1_err:0.234783
# [56]	validation_0-error:0.011969	validation_0-f1_err:0.234783
# [57]	validation_0-error:0.012135	validation_0-f1_err:0.241379
# [58]	validation_0-error:0.011859	validation_0-f1_err:0.241379
# Stopping. Best iteration:
# [33]	validation_0-error:0.013047	validation_0-f1_err:0.221239
#
# 2-fold / 4 completed!
# [0]	validation_0-error:0.05078	validation_0-f1_err:0.431953
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.026565	validation_0-f1_err:0.396226
# [2]	validation_0-error:0.02427	validation_0-f1_err:0.396226
# [3]	validation_0-error:0.026565	validation_0-f1_err:0.255814
# [4]	validation_0-error:0.026039	validation_0-f1_err:0.179487
# [5]	validation_0-error:0.031955	validation_0-f1_err:0.179487
# [6]	validation_0-error:0.029578	validation_0-f1_err:0.179487
# [7]	validation_0-error:0.023496	validation_0-f1_err:0.179487
# [8]	validation_0-error:0.023413	validation_0-f1_err:0.179487
# [9]	validation_0-error:0.020787	validation_0-f1_err:0.179487
# [10]	validation_0-error:0.020981	validation_0-f1_err:0.179487
# [11]	validation_0-error:0.020566	validation_0-f1_err:0.179487
# [12]	validation_0-error:0.018327	validation_0-f1_err:0.157895
# [13]	validation_0-error:0.020179	validation_0-f1_err:0.157895
# [14]	validation_0-error:0.018272	validation_0-f1_err:0.168142
# [15]	validation_0-error:0.019709	validation_0-f1_err:0.168142
# [16]	validation_0-error:0.018272	validation_0-f1_err:0.168142
# [17]	validation_0-error:0.018216	validation_0-f1_err:0.160714
# [18]	validation_0-error:0.017387	validation_0-f1_err:0.160714
# [19]	validation_0-error:0.017525	validation_0-f1_err:0.160714
# [20]	validation_0-error:0.017581	validation_0-f1_err:0.160714
# [21]	validation_0-error:0.01794	validation_0-f1_err:0.160714
# [22]	validation_0-error:0.017691	validation_0-f1_err:0.160714
# [23]	validation_0-error:0.017608	validation_0-f1_err:0.160714
# [24]	validation_0-error:0.017443	validation_0-f1_err:0.160714
# [25]	validation_0-error:0.017443	validation_0-f1_err:0.160714
# [26]	validation_0-error:0.016862	validation_0-f1_err:0.140351
# [27]	validation_0-error:0.01689	validation_0-f1_err:0.140351
# [28]	validation_0-error:0.016696	validation_0-f1_err:0.140351
# [29]	validation_0-error:0.01653	validation_0-f1_err:0.140351
# [30]	validation_0-error:0.016696	validation_0-f1_err:0.140351
# [31]	validation_0-error:0.016503	validation_0-f1_err:0.140351
# [32]	validation_0-error:0.016613	validation_0-f1_err:0.140351
# [33]	validation_0-error:0.016088	validation_0-f1_err:0.140351
# [34]	validation_0-error:0.016116	validation_0-f1_err:0.140351
# [35]	validation_0-error:0.016282	validation_0-f1_err:0.140351
# [36]	validation_0-error:0.01595	validation_0-f1_err:0.140351
# [37]	validation_0-error:0.015867	validation_0-f1_err:0.140351
# [38]	validation_0-error:0.015369	validation_0-f1_err:0.147826
# [39]	validation_0-error:0.015397	validation_0-f1_err:0.147826
# [40]	validation_0-error:0.015038	validation_0-f1_err:0.135593
# [41]	validation_0-error:0.014899	validation_0-f1_err:0.142857
# [42]	validation_0-error:0.014816	validation_0-f1_err:0.135593
# [43]	validation_0-error:0.014125	validation_0-f1_err:0.128205
# [44]	validation_0-error:0.014098	validation_0-f1_err:0.128205
# [45]	validation_0-error:0.01396	validation_0-f1_err:0.128205
# [46]	validation_0-error:0.013987	validation_0-f1_err:0.128205
# [47]	validation_0-error:0.013573	validation_0-f1_err:0.135593
# [48]	validation_0-error:0.013296	validation_0-f1_err:0.137931
# [49]	validation_0-error:0.013462	validation_0-f1_err:0.137931
# [50]	validation_0-error:0.012964	validation_0-f1_err:0.137931
# [51]	validation_0-error:0.012992	validation_0-f1_err:0.137931
# [52]	validation_0-error:0.013213	validation_0-f1_err:0.137931
# [53]	validation_0-error:0.013103	validation_0-f1_err:0.133333
# [54]	validation_0-error:0.012854	validation_0-f1_err:0.135593
# [55]	validation_0-error:0.012826	validation_0-f1_err:0.128205
# [56]	validation_0-error:0.012881	validation_0-f1_err:0.133333
# [57]	validation_0-error:0.01266	validation_0-f1_err:0.12605
# [58]	validation_0-error:0.012854	validation_0-f1_err:0.12605
# [59]	validation_0-error:0.011859	validation_0-f1_err:0.133333
# [60]	validation_0-error:0.012218	validation_0-f1_err:0.133333
# [61]	validation_0-error:0.011914	validation_0-f1_err:0.133333
# [62]	validation_0-error:0.011444	validation_0-f1_err:0.133333
# [63]	validation_0-error:0.011361	validation_0-f1_err:0.133333
# [64]	validation_0-error:0.011168	validation_0-f1_err:0.133333
# [65]	validation_0-error:0.011029	validation_0-f1_err:0.133333
# [66]	validation_0-error:0.010864	validation_0-f1_err:0.133333
# [67]	validation_0-error:0.010477	validation_0-f1_err:0.133333
# [68]	validation_0-error:0.010449	validation_0-f1_err:0.133333
# [69]	validation_0-error:0.010421	validation_0-f1_err:0.133333
# [70]	validation_0-error:0.0102	validation_0-f1_err:0.133333
# [71]	validation_0-error:0.009979	validation_0-f1_err:0.133333
# [72]	validation_0-error:0.009758	validation_0-f1_err:0.12605
# [73]	validation_0-error:0.009481	validation_0-f1_err:0.133333
# [74]	validation_0-error:0.009343	validation_0-f1_err:0.133333
# [75]	validation_0-error:0.009205	validation_0-f1_err:0.133333
# [76]	validation_0-error:0.009371	validation_0-f1_err:0.128205
# [77]	validation_0-error:0.009122	validation_0-f1_err:0.133333
# [78]	validation_0-error:0.009122	validation_0-f1_err:0.133333
# [79]	validation_0-error:0.009122	validation_0-f1_err:0.12605
# [80]	validation_0-error:0.008597	validation_0-f1_err:0.12605
# [81]	validation_0-error:0.008625	validation_0-f1_err:0.12605
# [82]	validation_0-error:0.008376	validation_0-f1_err:0.12605
# Stopping. Best iteration:
# [57]	validation_0-error:0.01266	validation_0-f1_err:0.12605
#
# 3-fold / 4 completed!
# [0]	validation_0-error:0.029578	validation_0-f1_err:0.521531
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 25 rounds.
# [1]	validation_0-error:0.022667	validation_0-f1_err:0.3
# [2]	validation_0-error:0.028693	validation_0-f1_err:0.3
# [3]	validation_0-error:0.020953	validation_0-f1_err:0.228346
# [4]	validation_0-error:0.0204	validation_0-f1_err:0.209677
# [5]	validation_0-error:0.020594	validation_0-f1_err:0.196581
# [6]	validation_0-error:0.017028	validation_0-f1_err:0.189655
# [7]	validation_0-error:0.014015	validation_0-f1_err:0.189655
# [8]	validation_0-error:0.016392	validation_0-f1_err:0.189655
# [9]	validation_0-error:0.013821	validation_0-f1_err:0.189655
# [10]	validation_0-error:0.013766	validation_0-f1_err:0.169492
# [11]	validation_0-error:0.013324	validation_0-f1_err:0.169492
# [12]	validation_0-error:0.013738	validation_0-f1_err:0.169492
# [13]	validation_0-error:0.013241	validation_0-f1_err:0.169492
# [14]	validation_0-error:0.013379	validation_0-f1_err:0.169492
# [15]	validation_0-error:0.012964	validation_0-f1_err:0.169492
# [16]	validation_0-error:0.012743	validation_0-f1_err:0.155172
# [17]	validation_0-error:0.012605	validation_0-f1_err:0.155172
# [18]	validation_0-error:0.013047	validation_0-f1_err:0.147826
# [19]	validation_0-error:0.013296	validation_0-f1_err:0.147826
# [20]	validation_0-error:0.013296	validation_0-f1_err:0.147826
# [21]	validation_0-error:0.013186	validation_0-f1_err:0.147826
# [22]	validation_0-error:0.013545	validation_0-f1_err:0.150442
# [23]	validation_0-error:0.013794	validation_0-f1_err:0.140351
# [24]	validation_0-error:0.013821	validation_0-f1_err:0.140351
# [25]	validation_0-error:0.013573	validation_0-f1_err:0.140351
# [26]	validation_0-error:0.013628	validation_0-f1_err:0.140351
# [27]	validation_0-error:0.013766	validation_0-f1_err:0.140351
# [28]	validation_0-error:0.013738	validation_0-f1_err:0.140351
# [29]	validation_0-error:0.013794	validation_0-f1_err:0.140351
# [30]	validation_0-error:0.013821	validation_0-f1_err:0.150442
# [31]	validation_0-error:0.013738	validation_0-f1_err:0.150442
# [32]	validation_0-error:0.0136	validation_0-f1_err:0.150442
# [33]	validation_0-error:0.013738	validation_0-f1_err:0.150442
# [34]	validation_0-error:0.013324	validation_0-f1_err:0.150442
# [35]	validation_0-error:0.013213	validation_0-f1_err:0.130435
# [36]	validation_0-error:0.01313	validation_0-f1_err:0.130435
# [37]	validation_0-error:0.012854	validation_0-f1_err:0.140351
# [38]	validation_0-error:0.012964	validation_0-f1_err:0.140351
# [39]	validation_0-error:0.012716	validation_0-f1_err:0.140351
# [40]	validation_0-error:0.012771	validation_0-f1_err:0.140351
# [41]	validation_0-error:0.013075	validation_0-f1_err:0.140351
# [42]	validation_0-error:0.013241	validation_0-f1_err:0.140351
# [43]	validation_0-error:0.013103	validation_0-f1_err:0.140351
# [44]	validation_0-error:0.013351	validation_0-f1_err:0.140351
# [45]	validation_0-error:0.013434	validation_0-f1_err:0.145299
# [46]	validation_0-error:0.013573	validation_0-f1_err:0.145299
# [47]	validation_0-error:0.013324	validation_0-f1_err:0.140351
# [48]	validation_0-error:0.013158	validation_0-f1_err:0.145299
# [49]	validation_0-error:0.012964	validation_0-f1_err:0.137931
# [50]	validation_0-error:0.013296	validation_0-f1_err:0.137931
# [51]	validation_0-error:0.013407	validation_0-f1_err:0.137931
# [52]	validation_0-error:0.013434	validation_0-f1_err:0.137931
# [53]	validation_0-error:0.013434	validation_0-f1_err:0.137931
# [54]	validation_0-error:0.013103	validation_0-f1_err:0.145299
# [55]	validation_0-error:0.012633	validation_0-f1_err:0.159664
# [56]	validation_0-error:0.012522	validation_0-f1_err:0.152542
# [57]	validation_0-error:0.012605	validation_0-f1_err:0.147826
# [58]	validation_0-error:0.012522	validation_0-f1_err:0.152542
# [59]	validation_0-error:0.012163	validation_0-f1_err:0.145299
# [60]	validation_0-error:0.012025	validation_0-f1_err:0.145299
# Stopping. Best iteration:
# [35]	validation_0-error:0.013213	validation_0-f1_err:0.130435
#
# 4-fold / 4 completed!
# Metric value (Train): 0.20 ± 0.00
# Metric value(Val): 0.18 ± 0.01

# %% [markdown]
# ## Using sklearn function for CV (Preferred)
#
# Even if it is easy to build the CV loop, and we can change the metric and the outputs in a personalized way, using a `for` loop makes the CV step non parallelizable (we could use the library `multiprocessing`) to solve this, but `sklearn` has implemented such an utility.
#
# These utilities can be found in sklearn's [webpage](https://scikit-learn.org/stable/modules/classes.html#model-validation). Some of them are:
# * [cross_val_score](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html) : Returning the validation score for some given metric.
# * [cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html#sklearn.model_selection.cross_validate) : Evaluate metric(s) by cross-validation and also record fit/score times. It can also returns the train metric.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
